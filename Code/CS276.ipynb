# %%
print('Ready to demolish')
# Out:
# Ready to demolish

# %%
# %%time
import os
PATH= './CS276/pa1-data/0/'
for root, dirs, files in os.walk(PATH):
    for file in files:
        print(file)
# Out:
# cmems.stanford.edu_people_dylan-montanari
# adg.stanford.edu_aa241_structures_weightstatements.html
# ccal.stanford.edu_case_case2_video.html
# blogs.law.stanford.edu_newsfeed_2010_09_
# chemtoolkit.stanford.edu_IncidentReporting
# adminguide.stanford.edu_12_13.pdf
# ccrma-mail.stanford.edu_pipermail_stk_2010-December_000767.html
# cmems.stanford.edu_people_will-sherman
# apir.stanford.edu_apir-l_members
# cosmarine.stanford.edu_campus-liaisons-marine-2011-2012
# benefits.stanford.edu_cgi-bin_compare_dental_retiree_2012_
# answers.stanford.edu_solution_im-using-afs-why-doesnt-autologout-accept-my-password-anymore
# cmems.stanford.edu_people_kevin-hilke
# arcade.stanford.edu_journals_rofl_authors_j-g-pocock
# alumni.gsb.stanford.edu_reunions_alumniweekend_index.html
# alpineclub.stanford.edu_curriculum_unclean_unclean.htm
# cpima.stanford.edu_highlights_cpima-sure-student-highlight-vivian-trang_
# alumni.stanford.edu_get_page_perks_bofa
# ...

# %%
# %%time
## On va compter tous les tokens
## On ouvre à chaque fois le fichier, on compte et on le ferme
TOTAL_TOKENS = 0

for root, dirs, files in os.walk(PATH):
    for file in files:
        with open(PATH + file, 'r') as f:
            TOTAL_TOKENS += len(f.readlines()[0].split(' '))

print(TOTAL_TOKENS)
# Out:
# 2693791
# CPU times: user 579 ms, sys: 208 ms, total: 787 ms
# Wall time: 792 ms

# %%
import nltk

# %%
with open(PATH + "biochemistry.stanford.edu_education_graduate.html", 'r') as f:
    print(f.read())
# Out:
# graduate studies education biochemistry stanford university school of medicine stanford school of medicine biochemistry search this site only stanford medical sites ways to give find a person alumni lane library ways to give find a person graduate studies consider biochemistry at stanford and choose from more than 135 labs in 11 departments at the forefront of research in the biosciences the best of both worlds at stanford our joint admissions program in the biosciences is based on a unique home program concept which means that you may enter the small and close knit department of biochemistry while reserving the opportunity to rotate through several labs during your first year before selecting your thesis advisor and program choose biochemistry as your home program if you share our interest in studying complex cellular process at a detailed molecular level stanford's department of biochemistry is housed in the beckman center a modern research facility outfitted with state of the art 
# ...
